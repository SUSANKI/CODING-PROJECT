# %% [markdown]
# OBJECTIVE: WE WILL USE LOGISTIC CLASSIFICATION TO IDENTIFY WHETHER THE TUMOR IS BENIGN OR MALIGNANT

# %%
from IPython.display import Image
Image(filename = "C:/Users/Win 10/Pictures/CELL.png", width = 800, height = 400)

# %%
Image(filename = "C:/Users/Win 10/Pictures/attribute.png", width = 300, height = 300)

# %% [markdown]
# #### IMPORT THE LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### IMPORT THE DATASET

# %%
data=pd.read_csv('C:/Users/Win 10/Desktop/MACHINE LEARNING/3. CLASSIFICATION/PROJECTS/1.BREAST CANCER WISCONSIN/breast_cancer.csv')
data.head(20)
# Out:
#     Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0              1000025                5                        1
# 1              1002945                5                        4
# 2              1015425                3                        1
# 3              1016277                6                        8
# 4              1017023                4                        1
# 5              1017122                8                       10
# 6              1018099                1                        1
# 7              1018561                2                        1
# 8              1033078                2                        1
# 9              1033078                4                        2
# 10             1035283                1                        1
# 11             1036172                2                        1
# 12             1041801                5                        3
# ...

# %% [markdown]
# ##### INTUITION

# %% [markdown]
# SO FIRSTLY, I WILL VISUALIZE BY PLOTTING THE DEPENDENT VARIABLE Y AGAINST ALL THE EXPLANATORY VARIABLE IN ORDER TO GET SOME FEELING AND FIND ANY IMPORTANT PATTERN ABOUT THE DATASET

# %%
data.columns
# Out:
# Index(['Sample code number', 'Clump Thickness', 'Uniformity of Cell Size',
#        'Uniformity of Cell Shape', 'Marginal Adhesion',
#        'Single Epithelial Cell Size', 'Bare Nuclei', 'Bland Chromatin',
#        'Normal Nucleoli', 'Mitoses', 'Class'],
#       dtype='object')

# %%
plt.scatter()
